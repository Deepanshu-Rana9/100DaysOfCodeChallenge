# %% [markdown]
# # DAY 29
# # Basic Pandas Questions

# %%
# Load the dataset using Pandas and display the first 5 rows.
import pandas as pd
df = pd.read_csv("C:\\Users\\Krishan Rana\\OneDrive\\Desktop\\Dataset used in Pandas\\Titanic_Dataset.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
# How many rows and columns does the dataset have?
df.shape
# Out:
# (418, 12)

# %%
# Display the column names of the dataset.
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# What are the data types of each column?
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
# Are there any missing values in the dataset?
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 413        False     False   False  False  False   True  False  False   False
# 414        False     False   False  False  False  False  False  False   False
# 415        False     False   False  False  False  False  False  False   False
# 416        False     False   False  False  False   True  False  False   False
# 417        False     False   False  False  False   True  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
# If so, which columns contain missing values?
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
# Retrieve the summary statistics of the numerical columns.
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
# Count the number of unique values in the "Sex" column.
df['Sex'].nunique()
# Out:
# 2

# %%
# Extract all rows where the passenger’s class (Pclass) is 1.
df1 = df[df['Pclass'] == 1]
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 11           903         0       1
# 12           904         1       1
# 14           906         1       1
# 20           912         0       1
# 22           914         1       1
# ..           ...       ...     ...
# 403         1295         0       1
# 404         1296         0       1
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 11                          Jones, Mr. Charles Cresson    male  46.0      0
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 20                              Rothschild, Mr. Martin    male  55.0      1
# 22                Flegenheim, Mrs. Alfred (Antoinette)  female   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Retrieve only the "Name" and "Age" columns.
df[["Name","Age"]]
# Out:
#                                              Name   Age
# 0                                Kelly, Mr. James  34.5
# 1                Wilkes, Mrs. James (Ellen Needs)  47.0
# 2                       Myles, Mr. Thomas Francis  62.0
# 3                                Wirz, Mr. Albert  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0
# ..                                            ...   ...
# 413                            Spector, Mr. Woolf   NaN
# 414                  Oliva y Ocana, Dona. Fermina  39.0
# 415                  Saether, Mr. Simon Sivertsen  38.5
# 416                           Ware, Mr. Frederick   NaN
# 417                      Peter, Master. Michael J   NaN
#
# [418 rows x 2 columns]

# %%
# Sort the dataset by "Fare" in descending order.
df.sort_values(by=['Fare'],ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 343         1235         1       1
# 53           945         1       1
# 69           961         1       1
# 24           916         1       1
# 142         1034         0       1
# ..           ...       ...     ...
# 133         1025         0       3
# 21           913         0       3
# 266         1158         0       1
# 372         1264         0       1
# 152         1044         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
# 53                          Fortune, Miss. Ethel Flora  female  28.0      3
# 69                 Fortune, Mrs. Mark (Mary McDougald)  female  60.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 142                         Ryerson, Mr. Arthur Larned    male  61.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # DAY 30
# # Intermediate Pandas Questions

# %%
# How many passengers survived vs. did not survive?
import pandas as pd

survived = df[df['Survived']==1]
not_survived = df[df['Survived']==0]

print(f"Number of passengers survived {len(survived)}")
print(f"Number of passengers not survived {len(not_survived)}")
# Out:
# Number of passengers survived 152
# Number of passengers not survived 266

# %%
# What is the average age of passengers?

avg_age = df['Age'].mean()
print(f"Average age of passengers is {avg_age}")
# Out:
# Average age of passengers is 30.272590361445783

# %%
# Fill the missing values in the "Age" column with the mean age.
df.fillna(df['Age'].mean())
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.50000      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.00000      1
# 2                       Myles, Mr. Thomas Francis    male  62.00000      0
# 3                                Wirz, Mr. Albert    male  27.00000      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# ...

# %%
# Find the most common port of embarkation.

most_common_embark = df['Embarked'].mode()[0]
print(f"Most common embarked is {most_common_embark}")
# Out:
# Most common embarked is S

# %%
# Find the passenger with the highest fare.
highest_fare = df['Fare'].max()
print(f"The highest fare is {highest_fare}")
# Out:
# The highest fare is 512.3292

# %%
# What is the average fare paid by passengers in each passenger class (Pclass)?
avg_fare_by_class = df.groupby('Pclass')["Fare"].mean()
print("The average fare paid by passengers in each Passenger class: ")
print(avg_fare_by_class)
# Out:
# The average fare paid by passengers in each Passenger class:
# Pclass
# 1    94.280297
# 2    22.202104
# 3    12.459678
# Name: Fare, dtype: float64

# %%
# Create a new column "FamilySize" by adding "SibSp" and "Parch".

df.insert(8,'FamilySize',df['SibSp'] + df['Parch'])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# replace "male" and "female" in the "Sex" column with 1 and 0, respectively.
df["Sex"]=df['Sex'].map({"male":1,"female":0})
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name  Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    1  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)    0  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    1  62.0      0      0
# 3                                Wirz, Mr. Albert    1  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0  22.0      1      1
# ..                                            ...  ...   ...    ...    ...
# ...

# %%
# Find the number of male and female passengers in each class.
no_of_male_female = df.groupby('Pclass')["Sex"].count()
print(f"Number of male and female passengers in each {no_of_male_female}")
# Out:
# Number of male and female passengers in each Pclass
# 1    107
# 2     93
# 3    218
# Name: Sex, dtype: int64

# %%
# Group passengers by "Embarked" and find the average fare for each embarkation port.
avg_fare_embark = df.groupby('Embarked')['Fare'].mean()
print(f"average fare for each {avg_fare_embark}")
# Out:
# average fare for each Embarked
# C    66.259765
# Q    10.957700
# S    28.230436
# Name: Fare, dtype: float64

# %% [markdown]
# # DAY 31
# # Advanced Pandas Questions

# %%
# Identify passengers who paid more than twice the average fare.
import pandas as pd
twice_fare = df[df['Fare']>df['Fare'].mean()]
twice_fare
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 20           912         0       1
# 23           915         0       1
# 24           916         1       1
# ..           ...       ...     ...
# 402         1294         1       1
# 403         1295         0       1
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name  Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)    0  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...    0  47.0      1
# 20                              Rothschild, Mr. Martin    1  55.0      1
# 23                     Williams, Mr. Richard Norris II    1  21.0      0
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)    0  48.0      1
# ..                                                 ...  ...   ...    ...
# ...

# %%
# Find the top 5 oldest passengers who survived.
old_survived = df.sort_values(['Age'],ascending = False)
old_survived.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 96           988         1       1
# 81           973         0       1
# 236         1128         0       1
# 305         1197         1       1
# 179         1071         1       1
#
#                                                   Name  Sex   Age  SibSp  \
# 96   Cavendish, Mrs. Tyrell William (Julia Florence...    0  76.0      1
# 81                                  Straus, Mr. Isidor    1  67.0      1
# 236                           Warren, Mr. Frank Manley    1  64.0      1
# 305  Crosby, Mrs. Edward Gifford (Catherine Elizabe...    0  64.0      1
# 179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...    0  64.0      0
#
#      Parch  FamilySize    Ticket      Fare    Cabin Embarked
# 96       0           1     19877   78.8500      C46        S
# 81       0           1  PC 17483  221.7792  C55 C57        S
# 236      0           1    110813   75.2500      D37        C
# 305      1           2    112901   26.5500      B26        S
# ...

# %%
# Create a new column "IsAlone" where it is 1 if "SibSp" and "Parch" are both 0, otherwise 0.
df['IsAlone'] = ((df['SibSp'] == 0) & (df['Parch'] == 0)).astype(int)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name  Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    1  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)    0  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    1  62.0      0      0
# 3                                Wirz, Mr. Albert    1  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0  22.0      1      1
# ..                                            ...  ...   ...    ...    ...
# ...

# %%
# Extract the last name of each passenger from the "Name" column.
for i in df['Name']:
    print(i.split(',')[0])
# Out:
# Kelly
# Wilkes
# Myles
# Wirz
# Hirvonen
# Svensson
# Connolly
# Caldwell
# Abrahim
# Davies
# Ilieff
# Jones
# Snyder
# Howard
# Chaffee
# del Carlo
# Keane
# Assaf
# Ilmakangas
# Assaf Khalil
# Rothschild
# Olsen
# Flegenheim
# Williams
# Ryerson
# Robins
# Ostby
# Daher
# Brady
# Samaan
# Louch
# Jefferys
# Dean
# Johnston
# Mock
# Katavelas
# Roth
# Cacic
# Sap
# Hee
# Karun
# Franklin
# Goldsmith
# Corbett
# Kimball
# Peltomaki
# Chevre
# Shaughnessy
# Bucknell
# Coutts
# Smith
# Pulbaum
# Hocking
# Fortune
# Mangiavacchi
# Rice
# Cor
# Abelseth
# Davison
# Chaudanson
# Dika
# McCrae
# Bjorklund
# Bradley
# Ryerson
# Corey
# Burns
# Moore
# Tucker
# Fortune
# Mulvihill
# Minkoff
# Nieminen
# Ovies y Rodriguez
# Geiger
# Keeping
# Miles
# Cornell
# Aldworth
# Doyle
# Boulos
# Straus
# Case
# Demetri
# Lamb
# Khalil
# Barry
# Badman
# O'Donoghue
# Wells
# Dyker
# Pedersen
# Davidson
# Guest
# Birnbaum
# Tenglin
# Cavendish
# Makinen
# Braf
# Nancarrow
# Stengel
# Weisz
# Foley
# ...

# %%
# Find the most expensive ticket price for each passenger class.
df.groupby('Pclass')['Fare'].max()
# Out:
# Pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: Fare, dtype: float64

# %%
df["Sex"]=df['Sex'].map({1:"male",0:"female"})
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# Determine the survival rate of passengers based on gender.
df.groupby('Sex')['Survived'].mean()*100
# Out:
# Sex
# female    100.0
# male        0.0
# Name: Survived, dtype: float64

# %%
# Replace missing values in the "Cabin" column with "Unknown".
df['Cabin'].fillna("Unknown", inplace =True)
df
# Out:
# C:\Users\Krishan Rana\AppData\Local\Temp\ipykernel_16920\3390110122.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Cabin'].fillna("Unknown", inplace =True)
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# ...

# %%
# Find passengers who have duplicate ticket numbers.
dup_ticket = df[df.duplicated('Ticket')]
dup_ticket
# Out:
#      PassengerId  Survived  Pclass  \
# 59           951         1       1
# 64           956         0       1
# 69           961         1       1
# 75           967         0       1
# 114         1006         1       1
# 122         1014         1       1
# 140         1032         1       3
# 142         1034         0       1
# 156         1048         1       1
# 172         1064         0       3
# 174         1066         0       3
# 177         1069         0       1
# 181         1073         0       1
# 210         1102         0       3
# 213         1105         1       2
# 218         1110         1       1
# 242         1134         0       1
# 244         1136         0       3
# 246         1138         1       2
# 247         1139         0       2
# 249         1141         1       3
# 262         1154         1       2
# 263         1155         1       3
# 270         1162         0       1
# 272         1164         1       1
# ...

# %%
# Convert the "Fare" column into categorical bins: Low (0-10), Medium (10-50), and High (50+).
bins = [0, 10, 50, float('inf')] 
labels = ['Low', 'Medium', 'High']

df['FareCategory'] = pd.cut(df['Fare'], bins=bins, labels=labels, right=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# Pivot the data to show the survival count by passenger class and gender.
pivot_table = df.pivot_table(values='Survived', index='Pclass', columns='Sex', aggfunc='sum')
pivot_table
# Out:
# Sex     female  male
# Pclass
# 1           50     0
# 2           30     0
# 3           72     0

# %% [markdown]
# # DAY 32
# # Advanced & Unique Pandas Questions

# %%
# Find the longest and shortest names in the dataset.
df['NameLength'] = df['Name'].apply(len)
longest_name = df.loc[df['NameLength'].idxmax(), "Name"]
shortest_name = df.loc[df['NameLength'].idxmin(), "Name"]
print(f"Longest Name is {longest_name}")
print(f"Shortest Name is {shortest_name}")
# Out:
# Longest Name is Cardeza, Mrs. James Warburton Martinez (Charlotte Wardle Drake)
# Shortest Name is Hee, Mr. Ling

# %%
# Find the ticket number that appears the most and list all passengers who had it.
most_frequent_ticket = df["Ticket"].mode()[0]
passengers_with_ticket = df[df["Ticket"] == most_frequent_ticket]["Name"].tolist()
passengers_with_ticket
# Out:
# ['Ryerson, Mrs. Arthur Larned (Emily Maria Borie)',
#  'Chaudanson, Miss. Victorine',
#  'Ryerson, Master. John Borie',
#  'Ryerson, Mr. Arthur Larned',
#  'Bowen, Miss. Grace Scott']

# %%
# Extract passengers whose age is an exact multiple of 5.
passengers_multiple_of_5 = df[df["Age"].notna() & (df["Age"] % 5 == 0)]
passengers_multiple_of_5
# Out:
#      PassengerId  Survived  Pclass  \
# 6            898         1       3
# 16           908         0       2
# 19           911         1       3
# 20           912         0       1
# 25           917         0       3
# ..           ...       ...     ...
# 378         1270         0       1
# 379         1271         0       3
# 400         1292         1       1
# 405         1297         0       2
# 407         1299         0       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 6                            Connolly, Miss. Kate  female  30.0      0      0
# 16                              Keane, Mr. Daniel    male  35.0      0      0
# 19          Assaf Khalil, Mrs. Mariana (Miriam")"  female  45.0      0      0
# 20                         Rothschild, Mr. Martin    male  55.0      1      0
# 25                        Robins, Mr. Alexander A    male  50.0      1      0
# ...

# %%
# Calculate the percentage of passengers with missing cabin information.
missing_cabin_percentage = df["Cabin"].isna().mean() * 100
missing_cabin_percentage
# Out:
# 0.0

# %%
# Find passengers who traveled with at least two family members (SibSp + Parch ≥ 2).
df["Family_Size"] = df["SibSp"] + df["Parch"]
passengers_with_family = df[df["Family_Size"] >= 2]
passengers_with_family
# Out:
#      PassengerId  Survived  Pclass  \
# 4            896         1       3
# 7            899         0       2
# 9            901         0       3
# 24           916         1       1
# 29           921         0       3
# ..           ...       ...     ...
# 394         1286         0       3
# 397         1289         1       1
# 407         1299         0       1
# 409         1301         1       3
# 417         1309         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 4         Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 7                         Caldwell, Mr. Albert Francis    male  26.0      1
# 9                              Davies, Mr. John Samuel    male  21.0      2
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 29                                   Samaan, Mr. Elias    male   NaN      2
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Create a new column "Title" by extracting titles (Mr., Mrs., Miss, etc.) from the "Name" column.
df["Title"] = df["Name"].apply(lambda x: x.split(",")[1].split(".")[0].strip())
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# Determine which title had the highest survival rate (Mr., Mrs., Miss, etc.).
title_survival_rates = df.groupby("Title")["Survived"].mean()
highest_survival_title = title_survival_rates.idxmax()
highest_survival_title
# Out:
# 'Dona'

# %%
# Calculate the interquartile range (IQR) for passenger fares.
Q1 = df["Fare"].quantile(0.25)
Q3 = df["Fare"].quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# 23.6042

# %%
# Find the proportion of passengers whose fare was higher than the median fare
median_fare = df["Fare"].median()
proportion_higher_than_median = (df["Fare"] > median_fare).mean()
proportion_higher_than_median
# Out:
# 0.49521531100478466

# %%
# Identify if there are any outliers in the "Fare" column using the Z-score method.
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers_fare = df[(df["Fare"] < lower_bound) | (df["Fare"] > upper_bound)]
outliers_fare
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 24           916         1       1
# 48           940         1       1
# 53           945         1       1
# 59           951         1       1
# 64           956         0       1
# 69           961         1       1
# 74           966         1       1
# 75           967         0       1
# 81           973         0       1
# 96           988         1       1
# 114         1006         1       1
# 118         1010         0       1
# 141         1033         1       1
# 142         1034         0       1
# 150         1042         1       1
# 156         1048         1       1
# 179         1071         1       1
# 181         1073         0       1
# 184         1076         1       1
# 188         1080         1       3
# 196         1088         0       1
# 202         1094         0       1
# 212         1104         0       2
# 217         1109         0       1
# ...

# %% [markdown]
# # DAY 33
# # Expert-Level Pandas Challenges

# %%
# Find the percentage of passengers whose ticket fare was exactly the same as another passenger.
dup_fares = df['Fare'].duplicated(keep=False)
per_dup_fares = (dup_fares.sum() / len(df)) * 100
print(f"Percentage of passengers with a duplicate fare: {per_dup_fares:.2f}%")
# Out:
# Percentage of passengers with a duplicate fare: 77.03%

# %%
# Create a new column "AgeGroup" that classifies ages into quartiles.
df['AgeGroup'] = pd.qcut(df['Age'], q=4, labels=['Q1', 'Q2', 'Q3', 'Q4'])
df[['Age', 'AgeGroup']].head()
# Out:
#     Age AgeGroup
# 0  34.5       Q3
# 1  47.0       Q4
# 2  62.0       Q4
# 3  27.0       Q2
# 4  22.0       Q2

# %%
# Survival rate based on cabin availability
df['HasCabin'] = df['Cabin'].notna()
survival_rate_cabin = df.groupby('HasCabin')['Survived'].mean()
print(f"Survival rate based on cabin availability:\n {survival_rate_cabin}")
# Out:
# Survival rate based on cabin availability:
#  HasCabin
# True    0.363636
# Name: Survived, dtype: float64

# %%
# Top 3 cabin letters with highest survival rate
df['CabinLetter'] = df['Cabin'].astype(str).str[0]
cabin_survive_rate = df.groupby('CabinLetter')['Survived'].mean().sort_values(ascending=False)
top_3_cabins = cabin_survive_rate.head(3)
print(f"Top 3 cabin letters with highest survival rate:\n {top_3_cabins}")
# Out:
# Top 3 cabin letters with highest survival rate:
#  CabinLetter
# G    1.000000
# C    0.542857
# B    0.500000
# Name: Survived, dtype: float64

# %%
# Fare per km (assuming Titanic traveled 3,000 km)
df['FarePerKm'] = df['Fare'] / 3000
df[['Fare', 'FarePerKm']].head()
# Out:
#       Fare  FarePerKm
# 0   7.8292   0.002610
# 1   7.0000   0.002333
# 2   9.6875   0.003229
# 3   8.6625   0.002887
# 4  12.2875   0.004096

# %% [markdown]
# # DAY 34

# %%
# Identify the five most expensive tickets in terms of fare per person (Fare / (SibSp + Parch + 1)).
df['FarePerPerson'] = df['Fare'] / (df['SibSp'] + df['Parch'] + 1)
top_5 = df.nlargest(5, 'FarePerPerson')
top_5[['Name', 'Fare', 'SibSp', 'Parch', 'FarePerPerson']]
# Out:
#                                                   Name      Fare  SibSp  \
# 59                         Chaudanson, Miss. Victorine  262.3750      0
# 375                           Bowen, Miss. Grace Scott  262.3750      0
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  512.3292      0
# 156                                  Bird, Miss. Ellen  221.7792      0
# 74                                Geiger, Miss. Amalie  211.5000      0
#
#      Parch  FarePerPerson
# 59       0       262.3750
# 375      0       262.3750
# 343      1       256.1646
# 156      0       221.7792
# 74       0       211.5000

# %%
# Find the survival rate of passengers who had duplicate names (excluding title differences).
df['CleanName'] = df['Name'].str.extract(r'([^,]+),')[0].str.strip()
dup_names = df[df.duplicated('CleanName', keep=False)]
survival_rate_dup_names = dup_names['Survived'].mean()
print(f"Survival rate of passengers with duplicate names: {survival_rate_dup_names:.2%}")
# Out:
# Survival rate of passengers with duplicate names: 40.34%

# %%
# Find the correlation between "Fare" and "Age"—does paying more indicate older passengers?
cor_fare_age = df[['Fare', 'Age']].corr().loc['Fare', 'Age']
print(f"Correlation between Fare and Age: {cor_fare_age:.2f}")
# Out:
# Correlation between Fare and Age: 0.34

# %%
# Find how many passengers had the exact same combination of "Pclass", "SibSp", and "Parch".
same_combination_count = df.duplicated(subset=['Pclass', 'SibSp', 'Parch'], keep=False).sum()
print(f"Number of passengers with the same Pclass, SibSp, and Parch combination: {same_combination_count}")
# Out:
# Number of passengers with the same Pclass, SibSp, and Parch combination: 407

# %%
# Find passengers whose name contains exactly two commas (indicating a complex title like "Countess, Lady").
complex_title_passengers = df[df['Name'].str.count(',') == 2]
print(complex_title_passengers[['Name']])
# Out:
# Empty DataFrame
# Columns: [Name]
# Index: []

# %% [markdown]
# # DAY 35

# %%
# Identify the most common first letter in passengers' last names.
df['LastNameFirstLetter'] = df['Name'].str[0]
most_common_lastname_letter = df['LastNameFirstLetter'].mode()[0]
print(f"Most common first letter in last names: {most_common_lastname_letter}")
# Out:
# Most common first letter in last names: C

# %%
# Find the longest ticket number in terms of character length.
longest_ticket = df.loc[df['Ticket'].str.len().idxmax(), 'Ticket']
print(f"Longest ticket number: {longest_ticket}")
# Out:
# Longest ticket number: SOTON/O.Q. 3101263

# %%
# Create a new column "CabinSection" by extracting only the first letter of the "Cabin" column.
df['CabinSection'] = df['Cabin'].astype(str).str[0]
df[['Cabin', 'CabinSection']].head()
# Out:
#      Cabin CabinSection
# 0  Unknown            U
# 1  Unknown            U
# 2  Unknown            U
# 3  Unknown            U
# 4  Unknown            U

# %%
# Check if any passengers have the same first name.
df['FirstName'] = df['Name'].str.extract(r'\. (\w+)')
duplicate_first_names = df[df.duplicated('FirstName', keep=False)]
duplicate_first_names[['Name', 'FirstName']]
# Out:
#                                                 Name  FirstName
# 0                                   Kelly, Mr. James      James
# 1                   Wilkes, Mrs. James (Ellen Needs)      James
# 2                          Myles, Mr. Thomas Francis     Thomas
# 3                                   Wirz, Mr. Albert     Albert
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  Alexander
# ..                                               ...        ...
# 407                       Widener, Mr. George Dunton     George
# 411  Minahan, Mrs. William Edward (Lillian E Thorpe)    William
# 415                     Saether, Mr. Simon Sivertsen      Simon
# 416                              Ware, Mr. Frederick  Frederick
# 417                         Peter, Master. Michael J    Michael
#
# [265 rows x 2 columns]

# %%
# Counting passengers with non-numeric ticket numbers
non_numeric_tickets = df['Ticket'].str.contains(r'\D', regex=True).sum()
print(f"Number of passengers with non-numeric ticket numbers: {non_numeric_tickets}")
# Out:
# Number of passengers with non-numeric ticket numbers: 122

# %% [markdown]
# # DAY 36

# %%
# Create a column that categorizes passengers as "Young", "Middle-aged", or "Senior" based on Age.
df['AgeCategory'] = pd.cut(df['Age'], bins=[0, 30, 60, 100], labels=['Young', 'Middle-aged', 'Senior'])
df[['Age', 'AgeCategory']].head()
# Out:
#     Age  AgeCategory
# 0  34.5  Middle-aged
# 1  47.0  Middle-aged
# 2  62.0       Senior
# 3  27.0        Young
# 4  22.0        Young

# %%
# Find passengers whose fare was greater than the median fare but who did not survive.
median_fare = df['Fare'].median()
high_fare_non_survivors = df[(df['Fare'] > median_fare) & (df['Survived'] == 0)]
high_fare_non_survivors[['Name', 'Fare', 'Survived']]
# Out:
#                              Name      Fare  Survived
# 7    Caldwell, Mr. Albert Francis   29.0000         0
# 9         Davies, Mr. John Samuel   24.1500         0
# 11     Jones, Mr. Charles Cresson   26.0000         0
# 13           Howard, Mr. Benjamin   26.0000         0
# 20         Rothschild, Mr. Martin   59.4000         0
# ..                            ...       ...       ...
# 401               Gale, Mr. Harry   21.0000         0
# 403        Carrau, Mr. Jose Pedro   47.1000         0
# 404  Frauenthal, Mr. Isaac Gerald   27.7208         0
# 407    Widener, Mr. George Dunton  211.5000         0
# 417      Peter, Master. Michael J   22.3583         0
#
# [111 rows x 3 columns]

# %%
# Replace missing values in the "Age" column with the median age per "Pclass".
df['Age'] = df['Age'].fillna(df.groupby('Pclass')['Age'].transform('median'))
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# Find the most common age in the dataset.
most_common_age = df['Age'].mode()[0]
print(f"Most common age: {most_common_age}")
# Out:
# Most common age: 24.0

# %%
# Find how many passengers have at least one missing value in their row.
missing_value_rows = df.isnull().any(axis=1).sum()
print(f"Number of passengers with at least one missing value: {missing_value_rows}")
# Out:
# Number of passengers with at least one missing value: 91

# %% [markdown]
# # DAY 37

# %%
# Determine the top 3 most common cabin sections (first letter of Cabin).
top_3_cabin_sections = df['Cabin'].dropna().astype(str).str[0].value_counts().head(3)
print("Top 3 most common cabin sections:\n", top_3_cabin_sections)
# Out:
# Top 3 most common cabin sections:
#  Cabin
# U    327
# C     35
# B     18
# Name: count, dtype: int64

# %%
# Identify passengers who paid the exact same fare as someone else but had a different class.
same_fare_diff_class = df[df.duplicated(subset=['Fare'], keep=False)].groupby('Fare').filter(lambda x: x['Pclass'].nunique() > 1)
same_fare_diff_class[['Name', 'Fare', 'Pclass']]
# Out:
#                                                   Name     Fare  Pclass
# 11                          Jones, Mr. Charles Cresson  26.0000       1
# 13                                Howard, Mr. Benjamin  26.0000       2
# 15       del Carlo, Mrs. Sebastiano (Argenia Genovesi)  27.7208       2
# 30                        Louch, Mr. Charles Alexander  26.0000       2
# 73                     Ovies y Rodriguez, Mr. Servando  27.7208       1
# 82                              Case, Mr. Howard Brown  26.0000       1
# 94                                 Birnbaum, Mr. Jakob  26.0000       1
# 101                                 Weisz, Mr. Leopold  26.0000       2
# 119    Chapman, Mrs. John Henry (Sara Elizabeth Lawry)  26.0000       2
# 143                         Beauchamp, Mr. Henry James  26.0000       2
# 149                             Lahtinen, Rev. William  26.0000       2
# 168  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...  27.7208       1
# ...

# %%
# Find the average fare per "Pclass" and "Embarked" group.
avg_fare_grouped = df.groupby(['Pclass', 'Embarked'])['Fare'].mean().unstack()
print("Average fare per Pclass and Embarked:\n", avg_fare_grouped)
# Out:
# Average fare per Pclass and Embarked:
#  Embarked           C          Q          S
# Pclass
# 1         110.073511  90.000000  76.677504
# 2          20.120445  11.273950  23.056090
# 3          10.658700   8.998985  13.913030

# %%
# Find passengers who had the same last name but were in different classes.
df['LastName'] = df['Name'].str.extract(r'(^[\w\-]+)')
same_lastname_diff_class = df[df.duplicated('LastName', keep=False)].groupby('LastName').filter(lambda x: x['Pclass'].nunique() > 1)
same_lastname_diff_class[['Name', 'LastName', 'Pclass']]
# Out:
#                                                   Name  LastName  Pclass
# 9                              Davies, Mr. John Samuel    Davies       3
# 13                                Howard, Mr. Benjamin    Howard       2
# 41                         Franklin, Mr. Thomas Parham  Franklin       1
# 147                                   Davies, Mr. Evan    Davies       3
# 175                          Brown, Miss. Edith Eileen     Brown       2
# 187                                 Davies, Mr. Joseph    Davies       3
# 213       Howard, Mrs. Benjamin (Ellen Truelove Arman)    Howard       2
# 236                           Warren, Mr. Frank Manley    Warren       1
# 260               de Messemaeker, Mr. Guillaume Joseph        de       3
# 267                        Warren, Mr. Charles William    Warren       3
# 268                        Howard, Miss. May Elizabeth    Howard       3
# 278                               Ware, Mr. John James      Ware       2
# ...

# %%
# Count how many passengers had their ticket number shared by at least 3 other passengers.
shared_tickets = df['Ticket'].value_counts()
tickets_with_3_or_more = shared_tickets[shared_tickets >= 3].index
passengers_with_shared_tickets = df[df['Ticket'].isin(tickets_with_3_or_more)].shape[0]
print(f"Number of passengers with a ticket shared by at least 3 others: {passengers_with_shared_tickets}")
# Out:
# Number of passengers with a ticket shared by at least 3 others: 31

# %% [markdown]
# # DAY 38

# %%
# Create a new column indicating whether a passenger had a known cabin or not (binary: 1 or 0).
df['HasCabin'] = df['Cabin'].notna().astype(int)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#    FamilySize   Ticket  ...  HasCabin CabinLetter FarePerKm  FarePerPerson  \
# 0           0   330911  ...         1           U  0.002610       7.829200
# 1           1   363272  ...         1           U  0.002333       3.500000
# 2           0   240276  ...         1           U  0.003229       9.687500
# ...

# %%
# Find the percentage of passengers who had a title other than "Mr.", "Mrs.", or "Miss".
df['Title'] = df['Name'].str.extract(r', (\w+)\.')
uncommon_title_percentage = (df[~df['Title'].isin(['Mr', 'Mrs', 'Miss'])].shape[0] / len(df)) * 100
print(f"Percentage of passengers with uncommon titles: {uncommon_title_percentage:.2f}%")
# Out:
# Percentage of passengers with uncommon titles: 6.70%

# %%
# Find the most expensive fare paid per "Pclass" and "Sex" combination.
max_fare_grouped = df.groupby(['Pclass', 'Sex'])['Fare'].max().unstack()
print("Most expensive fare per Pclass and Sex:\n", max_fare_grouped)
# Out:
# Most expensive fare per Pclass and Sex:
#  Sex       female     male
# Pclass
# 1       512.3292  262.375
# 2        65.0000   73.500
# 3        69.5500   69.550

# %%
# Check if there are any passengers who were traveling with both parents and siblings.
traveling_with_parents_and_siblings = df[(df['SibSp'] > 0) & (df['Parch'] > 0)]
print(f"Number of passengers traveling with both parents and siblings: {len(traveling_with_parents_and_siblings)}")
# Out:
# Number of passengers traveling with both parents and siblings: 64

# %% [markdown]
# # DAY 39
# # IMDB Movie Ratings

# %%
import pandas as pd
df2 = pd.read_csv("C:\\Users\\Krishan Rana\\OneDrive\\Desktop\\Dataset used in Pandas\\results_with_crew.csv")
df2
# Out:
#           tconst                                   primaryTitle  startYear  \
# 0      tt0111161                       The Shawshank Redemption       1994
# 1      tt0068646                                  The Godfather       1972
# 2      tt0468569                                The Dark Knight       2008
# 3      tt0167260  The Lord of the Rings: The Return of the King       2003
# 4      tt0108052                               Schindler's List       1993
# ...          ...                                            ...        ...
# 4995   tt0880578                                    Untraceable       2008
# 4996  tt27459160               Teri Baaton Mein Aisa Uljha Jiya       2024
# 4997   tt3174376                                  Before I Wake       2016
# 4998   tt5177088                   The Girl in the Spider's Web       2018
# 4999   tt8368408                            Gunpowder Milkshake       2021
#
# ...

# %%
# How many rows and columns are in the dataset?
df2.shape
# Out:
# (5000, 12)

# %%
# What are the column names and their data types?
df2.columns
# Out:
# Index(['tconst', 'primaryTitle', 'startYear', 'rank', 'averageRating',
#        'numVotes', 'runtimeMinutes', 'directors', 'writers', 'genres',
#        'IMDbLink', 'Title_IMDb_Link'],
#       dtype='object')

# %%
# Display the first 10 rows of the dataset.
df2.head(10)
# Out:
#       tconst                                       primaryTitle  startYear  \
# 0  tt0111161                           The Shawshank Redemption       1994
# 1  tt0068646                                      The Godfather       1972
# 2  tt0468569                                    The Dark Knight       2008
# 3  tt0167260      The Lord of the Rings: The Return of the King       2003
# 4  tt0108052                                   Schindler's List       1993
# 5  tt0071562                              The Godfather Part II       1974
# 6  tt0050083                                       12 Angry Men       1957
# 7  tt0110912                                       Pulp Fiction       1994
# 8  tt0120737  The Lord of the Rings: The Fellowship of the Ring       2001
# 9  tt1375666                                          Inception       2010
#
#    rank  averageRating  numVotes  runtimeMinutes             directors  \
# ...

# %%
# Display the last 5 rows of the dataset.
df2.tail()
# Out:
#           tconst                      primaryTitle  startYear  rank  \
# 4995   tt0880578                       Untraceable       2008  4996
# 4996  tt27459160  Teri Baaton Mein Aisa Uljha Jiya       2024  4997
# 4997   tt3174376                     Before I Wake       2016  4998
# 4998   tt5177088      The Girl in the Spider's Web       2018  4999
# 4999   tt8368408               Gunpowder Milkshake       2021  5000
#
#       averageRating  numVotes  runtimeMinutes                 directors  \
# 4995            6.2     54012             101            Gregory Hoblit
# 4996            6.2     53979             141  Amit Joshi, Aradhana Sah
# 4997            6.2     53934              97             Mike Flanagan
# 4998            6.1     53870             115              Fede Alvarez
# 4999            6.1     53710             114           Navot Papushado
#
#                                                 writers  \
# 4995     Robert Fyvolent, Mark Brinker, Allison Burnett
# ...

# %%
# Check for missing values in each column.
df2.isnull().sum()
# Out:
# tconst              0
# primaryTitle        0
# startYear           0
# rank                0
# averageRating       0
# numVotes            0
# runtimeMinutes      0
# directors           0
# writers            26
# genres              0
# IMDbLink            0
# Title_IMDb_Link     0
# dtype: int64

# %%
# Get summary statistics for numeric columns.
df2.describe()
# Out:
#          startYear         rank  averageRating      numVotes  runtimeMinutes
# count  5000.000000  5000.000000    5000.000000  5.000000e+03      5000.00000
# mean   2002.021200  2500.500000       7.137140  1.630208e+05       114.56380
# std      18.262844  1443.520003       0.597229  2.403863e+05        23.21629
# min    1915.000000     1.000000       5.900000  2.500000e+04        25.00000
# 25%    1994.000000  1250.750000       6.700000  4.008425e+04        99.00000
# 50%    2007.000000  2500.500000       7.100000  7.438750e+04       111.00000
# 75%    2015.000000  3750.250000       7.600000  1.780925e+05       126.00000
# max    2025.000000  5000.000000       9.300000  3.029407e+06       374.00000

# %%
# Show all movies released after the year 2010.
df2[df2['startYear']>2010]
# Out:
#           tconst                      primaryTitle  startYear  rank  \
# 14     tt0816692                      Interstellar       2014    15
# 28    tt15097216                          Jai Bhim       2021    29
# 29    tt23849204                         12th Fail       2023    30
# 30     tt1853728                  Django Unchained       2012    31
# 39     tt2582802                          Whiplash       2014    40
# ...          ...                               ...        ...   ...
# 4993   tt1660648                    Ricky Stanicky       2024  4994
# 4996  tt27459160  Teri Baaton Mein Aisa Uljha Jiya       2024  4997
# 4997   tt3174376                     Before I Wake       2016  4998
# 4998   tt5177088      The Girl in the Spider's Web       2018  4999
# 4999   tt8368408               Gunpowder Milkshake       2021  5000
#
#       averageRating  numVotes  runtimeMinutes                 directors  \
# 14              8.7   2326479             169         Christopher Nolan
# ...

# %%
# Display movies with an average rating greater than 8.5.
df2[df2['averageRating']>8.5]
# Out:
#          tconst                                       primaryTitle  startYear  \
# 0     tt0111161                           The Shawshank Redemption       1994
# 1     tt0068646                                      The Godfather       1972
# 2     tt0468569                                    The Dark Knight       2008
# 3     tt0167260      The Lord of the Rings: The Return of the King       2003
# 4     tt0108052                                   Schindler's List       1993
# 5     tt0071562                              The Godfather Part II       1974
# 6     tt0050083                                       12 Angry Men       1957
# 7     tt0110912                                       Pulp Fiction       1994
# 8     tt0120737  The Lord of the Rings: The Fellowship of the Ring       2001
# 9     tt1375666                                          Inception       2010
# 10    tt0137523                                         Fight Club       1999
# ...

# %%
# List movies directed by "Christopher Nolan".
df3 = df2[df2['directors']=="Christopher Nolan"]
movies_list_by_CN = list(df3['primaryTitle'])
movies_list_by_CN
# Out:
# ['The Dark Knight',
#  'Inception',
#  'Interstellar',
#  'The Prestige',
#  'The Dark Knight Rises',
#  'Memento',
#  'Oppenheimer',
#  'Batman Begins',
#  'Dunkirk',
#  'Following',
#  'Tenet',
#  'Insomnia']

# %%
# Find all movies in the genre "Drama".
df2[df2['genres']=="Drama"]
# Out:
#           tconst                     primaryTitle  startYear  rank  \
# 0      tt0111161         The Shawshank Redemption       1994     1
# 18     tt0073486  One Flew Over the Cuckoo's Nest       1975    19
# 48    tt10189514                  Soorarai Pottru       2020    49
# 63    tt10811166                The Kashmir Files       2022    64
# 72     tt0169547                  American Beauty       1999    73
# ...          ...                              ...        ...   ...
# 4099   tt0304415                  Mona Lisa Smile       2003  4100
# 4241   tt3442006                             Cake       2014  4242
# 4326   tt9000224                    The Assistant       2019  4327
# 4543   tt0115964                            Crash       1996  4544
# 4712   tt2479800                        Palo Alto       2013  4713
#
#       averageRating  numVotes  runtimeMinutes         directors  \
# 0               9.3   3029407             142    Frank Darabont
# ...

# %%
# Display movies with a runtime greater than 180 minutes.
df2[df2['runtimeMinutes']>180]
# Out:
#           tconst                                   primaryTitle  startYear  \
# 3      tt0167260  The Lord of the Rings: The Return of the King       2003
# 4      tt0108052                               Schindler's List       1993
# 5      tt0071562                          The Godfather Part II       1974
# 23     tt0120689                                 The Green Mile       1999
# 47     tt0047478                                  Seven Samurai       1954
# ...          ...                                            ...        ...
# 2702   tt0213890                                    Mohabbatein       2000
# 2717   tt0113987                                          Nixon       1995
# 3348   tt0111756                                     Wyatt Earp       1994
# 3430  tt17505010          Horizon: An American Saga - Chapter 1       2024
# 4756   tt0004972                          The Birth of a Nation       1915
#
# ...

# %%
# Show movies that have more than 1 million votes.
df2[df2['numVotes']>1000000]
# Out:
#          tconst                                   primaryTitle  startYear  \
# 0     tt0111161                       The Shawshank Redemption       1994
# 1     tt0068646                                  The Godfather       1972
# 2     tt0468569                                The Dark Knight       2008
# 3     tt0167260  The Lord of the Rings: The Return of the King       2003
# 4     tt0108052                               Schindler's List       1993
# ...         ...                                            ...        ...
# 218   tt1431045                                       Deadpool       2016
# 308   tt0499549                                         Avatar       2009
# 309   tt0120338                                        Titanic       1997
# 310   tt0371746                                       Iron Man       2008
# 2078  tt1392170                               The Hunger Games       2012
#
#       rank  averageRating  numVotes  runtimeMinutes             directors  \
# ...

# %%
# Sort the dataset by averageRating in descending order.
df2.sort_values(['averageRating'],ascending=False)
# Out:
#          tconst                                   primaryTitle  startYear  \
# 0     tt0111161                       The Shawshank Redemption       1994
# 49    tt0252487                                The Chaos Class       1975
# 1     tt0068646                                  The Godfather       1972
# 3     tt0167260  The Lord of the Rings: The Return of the King       2003
# 6     tt0050083                                   12 Angry Men       1957
# ...         ...                                            ...        ...
# 4742  tt0069089                                 Pink Flamingos       1972
# 4741  tt0092796                                    Creepshow 2       1987
# 4781  tt0160916                                The Story of Us       1999
# 4789  tt0323033                             Laws of Attraction       2004
# 4788  tt0100114                               Marked for Death       1990
#
#       rank  averageRating  numVotes  runtimeMinutes             directors  \
# ...

# %%
# Sort the dataset by numVotes and runtimeMinutes, both in descending order.
df2.sort_values(['numVotes','runtimeMinutes'],ascending = False)
# Out:
#           tconst              primaryTitle  startYear  rank  averageRating  \
# 0      tt0111161  The Shawshank Redemption       1994     1            9.3
# 2      tt0468569           The Dark Knight       2008     3            9.0
# 9      tt1375666                 Inception       2010    10            8.8
# 10     tt0137523                Fight Club       1999    11            8.8
# 11     tt0109830              Forrest Gump       1994    12            8.8
# ...          ...                       ...        ...   ...            ...
# 2358  tt21626774                 Sector 36       2024  2359            7.1
# 4355   tt0276816                     Below       2002  4356            6.1
# 801    tt2659414     Miracle in Cell No. 7       2013   802            8.1
# 3980   tt0338427                  Shopgirl       2005  3981            6.3
# 3167   tt0924129             Crossing Over       2009  3168            6.7
#
#       numVotes  runtimeMinutes          directors  \
# ...

# %%
# Show the top 10 longest movies by runtime.
longest_movies = df2.sort_values(['runtimeMinutes'],ascending = False)
longest_movies.head(10)
# Out:
#           tconst                  primaryTitle  startYear  rank  \
# 420    tt0346336             The Best of Youth       2003   421
# 283    tt1954470            Gangs of Wasseypur       2012   284
# 2670   tt0056937                     Cleopatra       1963  2671
# 1635   tt0074084                          1900       1976  1636
# 1604   tt0107007                    Gettysburg       1993  1605
# 1259   tt0116477                        Hamlet       1996  1260
# 331   tt12361974  Zack Snyder's Justice League       2021   332
# 190    tt0031381            Gone with the Wind       1939   191
# 129    tt0087843   Once Upon a Time in America       1984   130
# 133    tt0056172            Lawrence of Arabia       1962   134
#
#       averageRating  numVotes  runtimeMinutes  \
# 420             8.5     25253             374
# 283             8.2    107153             321
# 2670            7.0     39076             320
# 1635            7.6     28166             317
# ...

# %%
# What is the average rating for each genre?
rating_genre = df2.groupby('genres')['averageRating'].mean()
print(f"The Average Rating of movies of eacg genres:\n{rating_genre}")
# Out:
# The Average Rating of movies of eacg genres:
# genres
# Action                          6.200000
# Action, Adventure               7.900000
# Action, Adventure, Animation    7.154412
# Action, Adventure, Biography    6.880000
# Action, Adventure, Comedy       6.961194
#                                   ...
# Romance, Sci-Fi                 7.000000
# Sci-Fi, Thriller                7.200000
# Thriller                        6.650000
# Thriller, Western               7.000000
# Western                         8.250000
# Name: averageRating, Length: 359, dtype: float64

# %%
# What is the total number of votes per genre?
votes_per_genre = df2.groupby('genres')['numVotes'].sum()
print(f"Total number of votes per genre: \n{votes_per_genre}")
# Out:
# Total number of votes per genre:
# genres
# Action                             32466
# Action, Adventure                2874764
# Action, Adventure, Animation    12424238
# Action, Adventure, Biography      399551
# Action, Adventure, Comedy       16704380
#                                   ...
# Romance, Sci-Fi                    54801
# Sci-Fi, Thriller                  976362
# Thriller                          255345
# Thriller, Western                  46923
# Western                          1852046
# Name: numVotes, Length: 359, dtype: int64

# %%
# Find the average runtime of movies released each year.
avg_run_per_year = df2.groupby('startYear')['runtimeMinutes'].mean()
print(f"Average runtime of movies released in each year: \n{avg_run_per_year}")
# Out:
# Average runtime of movies released in each year:
# startYear
# 1915    195.000000
# 1920     67.000000
# 1921     68.000000
# 1922     94.000000
# 1924     45.000000
#            ...
# 2021    123.132231
# 2022    123.522727
# 2023    122.284615
# 2024    124.946809
# 2025    124.125000
# Name: runtimeMinutes, Length: 106, dtype: float64

# %%
# Count how many movies each director has in the dataset.
num_movies = df2.groupby('directors')['primaryTitle'].count()
print(f"Number of movies by each director: \n{num_movies}")
# Out:
# Number of movies by each director:
# directors
# A.R. Murugadoss                                                5
# Aamir Khan                                                     1
# Aanand L. Rai                                                  3
# Aaron Blaise, Robert Walker                                    1
# Aaron Horvath, Michael Jelenic, Pierre Leduc, Fabien Polack    1
#                                                               ..
# Álex de la Iglesia                                             2
# Çagan Irmak                                                    1
# Éric Lartigau                                                  1
# Ömer Faruk Sorak                                               2
# Ömer Vargi                                                     1
# Name: primaryTitle, Length: 2278, dtype: int64

# %%
# Find the maximum and minimum ratings per director.
min_max_rating = df2.groupby('directors')['averageRating'].agg(['max','min'])
print(f"Maximum And Minimun Rating of each director :\n{min_max_rating}")
# Out:
# Maximum And Minimun Rating of each director :
#                                                     max  min
# directors
# A.R. Murugadoss                                     8.1  7.2
# Aamir Khan                                          8.3  8.3
# Aanand L. Rai                                       7.6  6.5
# Aaron Blaise, Robert Walker                         6.9  6.9
# Aaron Horvath, Michael Jelenic, Pierre Leduc, F...  7.0  7.0
# ...                                                 ...  ...
# Álex de la Iglesia                                  6.3  6.1
# Çagan Irmak                                         8.2  8.2
# Éric Lartigau                                       7.3  7.3
# Ömer Faruk Sorak                                    8.0  7.4
# Ömer Vargi                                          8.1  8.1
#
# [2278 rows x 2 columns]

# %%
# Create a new column called decade based on startYear.
df2['decade'] = (df2['startYear'] // 10) * 10
df2
# Out:
#           tconst                                   primaryTitle  startYear  \
# 0      tt0111161                       The Shawshank Redemption       1994
# 1      tt0068646                                  The Godfather       1972
# 2      tt0468569                                The Dark Knight       2008
# 3      tt0167260  The Lord of the Rings: The Return of the King       2003
# 4      tt0108052                               Schindler's List       1993
# ...          ...                                            ...        ...
# 4995   tt0880578                                    Untraceable       2008
# 4996  tt27459160               Teri Baaton Mein Aisa Uljha Jiya       2024
# 4997   tt3174376                                  Before I Wake       2016
# 4998   tt5177088                   The Girl in the Spider's Web       2018
# 4999   tt8368408                            Gunpowder Milkshake       2021
#
# ...

# %%
# Extract the first listed genre into a new column
df2['first_genre'] = df2['genres'].str.split(",").str[0]
df2
# Out:
#           tconst                                   primaryTitle  startYear  \
# 0      tt0111161                       The Shawshank Redemption       1994
# 1      tt0068646                                  The Godfather       1972
# 2      tt0468569                                The Dark Knight       2008
# 3      tt0167260  The Lord of the Rings: The Return of the King       2003
# 4      tt0108052                               Schindler's List       1993
# ...          ...                                            ...        ...
# 4995   tt0880578                                    Untraceable       2008
# 4996  tt27459160               Teri Baaton Mein Aisa Uljha Jiya       2024
# 4997   tt3174376                                  Before I Wake       2016
# 4998   tt5177088                   The Girl in the Spider's Web       2018
# 4999   tt8368408                            Gunpowder Milkshake       2021
#
# ...

# %%
# Create a column indicating whether a movie is a "Classic" (before 2000).
df2['generation'] = df2['startYear'].apply(lambda x: "Classic" if x < 2000 else "Modern")
df2
# Out:
#           tconst                                   primaryTitle  startYear  \
# 0      tt0111161                       The Shawshank Redemption       1994
# 1      tt0068646                                  The Godfather       1972
# 2      tt0468569                                The Dark Knight       2008
# 3      tt0167260  The Lord of the Rings: The Return of the King       2003
# 4      tt0108052                               Schindler's List       1993
# ...          ...                                            ...        ...
# 4995   tt0880578                                    Untraceable       2008
# 4996  tt27459160               Teri Baaton Mein Aisa Uljha Jiya       2024
# 4997   tt3174376                                  Before I Wake       2016
# 4998   tt5177088                   The Girl in the Spider's Web       2018
# 4999   tt8368408                            Gunpowder Milkshake       2021
#
# ...

# %%
# Create a new column categorizing movies as "Short", "Medium", or "Long" based on runtimeMinutes.
df2['length'] = pd.cut(df2['runtimeMinutes'],bins = [0,100,200,300], labels  = ['Short','Medium','Long'])
df2
# Out:
#           tconst                                   primaryTitle  startYear  \
# 0      tt0111161                       The Shawshank Redemption       1994
# 1      tt0068646                                  The Godfather       1972
# 2      tt0468569                                The Dark Knight       2008
# 3      tt0167260  The Lord of the Rings: The Return of the King       2003
# 4      tt0108052                               Schindler's List       1993
# ...          ...                                            ...        ...
# 4995   tt0880578                                    Untraceable       2008
# 4996  tt27459160               Teri Baaton Mein Aisa Uljha Jiya       2024
# 4997   tt3174376                                  Before I Wake       2016
# 4998   tt5177088                   The Girl in the Spider's Web       2018
# 4999   tt8368408                            Gunpowder Milkshake       2021
#
# ...

# %%
df2
# Out:
#           tconst                                   primaryTitle  startYear  \
# 0      tt0111161                       The Shawshank Redemption       1994
# 1      tt0068646                                  The Godfather       1972
# 2      tt0468569                                The Dark Knight       2008
# 3      tt0167260  The Lord of the Rings: The Return of the King       2003
# 4      tt0108052                               Schindler's List       1993
# ...          ...                                            ...        ...
# 4995   tt0880578                                    Untraceable       2008
# 4996  tt27459160               Teri Baaton Mein Aisa Uljha Jiya       2024
# 4997   tt3174376                                  Before I Wake       2016
# 4998   tt5177088                   The Girl in the Spider's Web       2018
# 4999   tt8368408                            Gunpowder Milkshake       2021
#
# ...

# %% [markdown]
# # DAY 40

# %%
# List all unique genres.
uni_genre = []

for genre_list in df2['genres']:
    if pd.notnull(genre_list):
        for genre in genre_list.split(','):
            if genre not in uni_genre:
                uni_genre.append(genre)

print(uni_genre)
# Out:
# ['Drama', 'Crime', ' Drama', 'Action', ' Crime', 'Adventure', ' Fantasy', 'Biography', ' History', ' Adventure', ' Sci-Fi', ' Thriller', ' Romance', ' Western', ' Mystery', ' Horror', ' War', ' Animation', ' Family', 'Comedy', 'Western', ' Comedy', ' Music', 'Horror', 'Mystery', 'Animation', ' Film-Noir', ' Biography', ' Musical', ' Documentary', ' Sport', 'Documentary', 'Fantasy', ' News', 'Thriller', 'Sci-Fi', 'Romance', 'Musical']

# %%
# Count how many movies have "Lord" in their title.
count_lord = df2['primaryTitle'].astype(str).str.contains('lord', case=False, na=False).sum()
print(f"Movies with 'Lord' in the title: {count_lord}")
# Out:
# Movies with 'Lord' in the title: 11

# %%
# Filter movies where the writer includes "Tolkien".
tolkien_movies = df2[df2['writers'].str.contains('tolkien', case=False, na=False)]
tolkien_movies[['primaryTitle', 'writers']]
# Out:
#                                            primaryTitle  \
# 3         The Lord of the Rings: The Return of the King
# 8     The Lord of the Rings: The Fellowship of the Ring
# 12                The Lord of the Rings: The Two Towers
# 422                   The Hobbit: An Unexpected Journey
# 430                 The Hobbit: The Desolation of Smaug
# 1334          The Hobbit: The Battle of the Five Armies
# 4311     The Lord of the Rings: The War of the Rohirrim
# 4673                              The Lord of the Rings
#
#                                                 writers
# 3     J.R.R. Tolkien, Fran Walsh, Philippa Boyens, P...
# 8     J.R.R. Tolkien, Fran Walsh, Philippa Boyens, P...
# 12    J.R.R. Tolkien, Fran Walsh, Philippa Boyens, S...
# 422   Fran Walsh, Philippa Boyens, Peter Jackson, Gu...
# 430   Fran Walsh, Philippa Boyens, Peter Jackson, Gu...
# 1334  Fran Walsh, Philippa Boyens, Peter Jackson, Gu...
# 4311  Jeffrey Addiss, Will Matthews, Phoebe Gittins,...
# ...

# %%
# Extract domain links from the IMDbLink column.
df2['imdb_domain'] = df2['IMDbLink'].str.extract(r'https?://(.*?)/')
df2
# Out:
#           tconst                                   primaryTitle  startYear  \
# 0      tt0111161                       The Shawshank Redemption       1994
# 1      tt0068646                                  The Godfather       1972
# 2      tt0468569                                The Dark Knight       2008
# 3      tt0167260  The Lord of the Rings: The Return of the King       2003
# 4      tt0108052                               Schindler's List       1993
# ...          ...                                            ...        ...
# 4995   tt0880578                                    Untraceable       2008
# 4996  tt27459160               Teri Baaton Mein Aisa Uljha Jiya       2024
# 4997   tt3174376                                  Before I Wake       2016
# 4998   tt5177088                   The Girl in the Spider's Web       2018
# 4999   tt8368408                            Gunpowder Milkshake       2021
#
# ...

# %%
# Clean the IMDbLink column to only show the actual URL.# 
df2['IMDbLink'] = df2['IMDbLink'].str.extract(r'(https?://[^\s]+)')
df2
# Out:
#           tconst                                   primaryTitle  startYear  \
# 0      tt0111161                       The Shawshank Redemption       1994
# 1      tt0068646                                  The Godfather       1972
# 2      tt0468569                                The Dark Knight       2008
# 3      tt0167260  The Lord of the Rings: The Return of the King       2003
# 4      tt0108052                               Schindler's List       1993
# ...          ...                                            ...        ...
# 4995   tt0880578                                    Untraceable       2008
# 4996  tt27459160               Teri Baaton Mein Aisa Uljha Jiya       2024
# 4997   tt3174376                                  Before I Wake       2016
# 4998   tt5177088                   The Girl in the Spider's Web       2018
# 4999   tt8368408                            Gunpowder Milkshake       2021
#
# ...

# %%
# Show movies that belong to both "Action" and "Drama".
action_drama = df2[
    df2['genres'].astype(str).str.contains('Action', case=False, na=False) &
    df2['genres'].astype(str).str.contains('Drama', case=False, na=False)
]
action_drama
# Out:
#          tconst            primaryTitle  startYear  rank  averageRating  \
# 2     tt0468569         The Dark Knight       2008     3            9.0
# 31    tt0172495               Gladiator       2000    32            8.5
# 35    tt0110413  Léon: The Professional       1994    36            8.5
# 47    tt0047478           Seven Samurai       1954    48            8.6
# 50    tt1345836   The Dark Knight Rises       2012    51            8.4
# ...         ...                     ...        ...   ...            ...
# 4930  tt1712261                Triple 9       2016  4931            6.3
# 4931  tt1137450              Death Wish       2018  4932            6.3
# 4943  tt0118972         The Devil's Own       1997  4944            6.2
# 4971  tt1135084                  Takers       2010  4972            6.2
# 4974  tt0087985                Red Dawn       1984  4975            6.3
#
#       numVotes  runtimeMinutes          directors  \
# 2      3005759             152  Christopher Nolan
# ...

# %%
# Display movies where numVotes > 500,000 and averageRating > 8.8.
popular_high_rated = df2[
    (df2['numVotes'] > 500_000) &
    (df2['averageRating'] > 8.8)
]
popular_high_rated
# Out:
#       tconst                                       primaryTitle  startYear  \
# 0  tt0111161                           The Shawshank Redemption       1994
# 1  tt0068646                                      The Godfather       1972
# 2  tt0468569                                    The Dark Knight       2008
# 3  tt0167260      The Lord of the Rings: The Return of the King       2003
# 4  tt0108052                                   Schindler's List       1993
# 5  tt0071562                              The Godfather Part II       1974
# 6  tt0050083                                       12 Angry Men       1957
# 7  tt0110912                                       Pulp Fiction       1994
# 8  tt0120737  The Lord of the Rings: The Fellowship of the Ring       2001
#
#    rank  averageRating  numVotes  runtimeMinutes             directors  \
# 0     1            9.3   3029407             142        Frank Darabont
# 1     2            9.2   2114342             175  Francis Ford Coppola
# ...

# %%
# Find all movies directed by either "Steven Spielberg" or "Peter Jackson".
director = df2[
    df2['directors'].astype(str).str.contains('Steven Spielberg|Peter Jackson', case=False, na=False)
]
director
# Out:
#           tconst                                       primaryTitle  \
# 3      tt0167260      The Lord of the Rings: The Return of the King
# 4      tt0108052                                   Schindler's List
# 8      tt0120737  The Lord of the Rings: The Fellowship of the Ring
# 12     tt0167261              The Lord of the Rings: The Two Towers
# 21     tt0120815                                Saving Private Ryan
# 57     tt0082971                            Raiders of the Lost Ark
# 105    tt0107290                                      Jurassic Park
# 114    tt0097576                 Indiana Jones and the Last Crusade
# 154    tt0264464                                Catch Me If You Can
# 171    tt0073195                                               Jaws
# 332    tt0083866                         E.T. the Extra-Terrestrial
# 422    tt0903624                  The Hobbit: An Unexpected Journey
# 430    tt1170358                The Hobbit: The Desolation of Smaug
# ...

# %%
# Filter for movies with missing or null values in the writers column.
missing_writers = df2[df2['writers'].isna() | (df2['writers'] == '')]
missing_writers
# Out:
#           tconst                              primaryTitle  startYear  rank  \
# 150   tt11989890  David Attenborough: A Life on Our Planet       2020   151
# 389    tt7775622                                 Free Solo       2018   390
# 545    tt4044364                               Citizenfour       2014   546
# 561   tt20256528                          What Is a Woman?       2022   562
# 565    tt2375605                        The Act of Killing       2012   566
# 572    tt7905466                   They Shall Not Grow Old       2018   573
# 579    tt0110057                               Hoop Dreams       1994   580
# 580    tt7681902                 Won't You Be My Neighbor?       2018   581
# 709    tt1587707                Exit Through the Gift Shop       2010   710
# 770   tt14152756                                Seaspiracy       2021   771
# 789    tt8760684                                 Apollo 11       2019   790
# ...

# %%
# Select movies with ratings in the top 1% of the dataset.
threshold = df2['averageRating'].quantile(0.99)
top_1_percent = df2[df2['averageRating'] >= threshold]
top_1_percent
# Out:
#          tconst                                   primaryTitle  startYear  \
# 0     tt0111161                       The Shawshank Redemption       1994
# 1     tt0068646                                  The Godfather       1972
# 2     tt0468569                                The Dark Knight       2008
# 3     tt0167260  The Lord of the Rings: The Return of the King       2003
# 4     tt0108052                               Schindler's List       1993
# ..          ...                                            ...        ...
# 416   tt0367495                                     Anbe Sivam       2003
# 417  tt11580854                            Sarpatta Parambarai       2021
# 418   tt0093603                                        Nayakan       1987
# 419  tt24082438                            20 Days in Mariupol       2023
# 420   tt0346336                              The Best of Youth       2003
#
#      rank  averageRating  numVotes  runtimeMinutes              directors  \
# ...

# %% [markdown]
# # DAY 41

# %% [markdown]
# # 🛍️ Amazon Sales Data Practice Notebook (Using Pandas)
#
# This notebook contains a series of data manipulation exercises using **Pandas** on an Amazon sales dataset.
# Each question is designed to help you practice data filtering, aggregation, transformation, and exploration.
#
# ---

# %%
import pandas as pd
df3 = pd.read_csv("C:\\Users\\Krishan Rana\\OneDrive\\Desktop\\Dataset used in Pandas\\amazon_sales_data 2025.csv")
df3.head()
# Out:
#   Order ID      Date        Product     Category  Price  Quantity  \
# 0  ORD0001  14-03-25  Running Shoes     Footwear     60         3
# 1  ORD0002  20-03-25     Headphones  Electronics    100         4
# 2  ORD0003  15-02-25  Running Shoes     Footwear     60         2
# 3  ORD0004  19-02-25  Running Shoes     Footwear     60         3
# 4  ORD0005  10-03-25     Smartwatch  Electronics    150         3
#
#    Total Sales  Customer Name Customer Location Payment Method     Status
# 0          180     Emma Clark          New York     Debit Card  Cancelled
# 1          400  Emily Johnson     San Francisco     Debit Card    Pending
# 2          120       John Doe            Denver     Amazon Pay  Cancelled
# 3          180  Olivia Wilson            Dallas    Credit Card    Pending
# 4          450     Emma Clark          New York     Debit Card    Pending

# %%
# 1. How many rows and columns are in the dataset?
df3.shape
# Out:
# (250, 11)

# %%
# 2. List all the column names and their data types.
df3.columns
# Out:
# Index(['Order ID', 'Date', 'Product', 'Category', 'Price', 'Quantity',
#        'Total Sales', 'Customer Name', 'Customer Location', 'Payment Method',
#        'Status'],
#       dtype='object')

# %%
# 3. Display the first 10 rows of the dataset.
df3.head(10)
# Out:
#   Order ID      Date        Product     Category  Price  Quantity  \
# 0  ORD0001  14-03-25  Running Shoes     Footwear     60         3
# 1  ORD0002  20-03-25     Headphones  Electronics    100         4
# 2  ORD0003  15-02-25  Running Shoes     Footwear     60         2
# 3  ORD0004  19-02-25  Running Shoes     Footwear     60         3
# 4  ORD0005  10-03-25     Smartwatch  Electronics    150         3
# 5  ORD0006  14-03-25        T-Shirt     Clothing     20         1
# 6  ORD0007  18-03-25     Smartwatch  Electronics    150         4
# 7  ORD0008  02-03-25     Smartphone  Electronics    500         1
# 8  ORD0009  08-03-25        T-Shirt     Clothing     20         3
# 9  ORD0010  12-03-25     Smartphone  Electronics    500         1
#
#    Total Sales  Customer Name Customer Location Payment Method     Status
# 0          180     Emma Clark          New York     Debit Card  Cancelled
# 1          400  Emily Johnson     San Francisco     Debit Card    Pending
# ...

# %%
# 4. Check for missing or null values in each column.
df3.isnull().sum()
# Out:
# Order ID             0
# Date                 0
# Product              0
# Category             0
# Price                0
# Quantity             0
# Total Sales          0
# Customer Name        0
# Customer Location    0
# Payment Method       0
# Status               0
# dtype: int64

# %%
# 5. Get summary statistics for `Price`, `Quantity`, and `Total Sales`.
df3.describe()
# Out:
#              Price    Quantity  Total Sales
# count   250.000000  250.000000   250.000000
# mean    343.580000    2.856000   975.380000
# std     380.635808    1.429489  1252.112254
# min      15.000000    1.000000    15.000000
# 25%      40.000000    2.000000   100.000000
# 50%     150.000000    3.000000   400.000000
# 75%     600.000000    4.000000  1500.000000
# max    1200.000000    5.000000  6000.000000

# %%
# 6. Show all orders with a `Total Sales` greater than 300.
df3[df3['Total Sales']>300]
# Out:
#     Order ID      Date     Product     Category  Price  Quantity  Total Sales  \
# 1    ORD0002  20-03-25  Headphones  Electronics    100         4          400
# 4    ORD0005  10-03-25  Smartwatch  Electronics    150         3          450
# 6    ORD0007  18-03-25  Smartwatch  Electronics    150         4          600
# 7    ORD0008  02-03-25  Smartphone  Electronics    500         1          500
# 9    ORD0010  12-03-25  Smartphone  Electronics    500         1          500
# ..       ...       ...         ...          ...    ...       ...          ...
# 241  ORD0242  08-03-25  Smartphone  Electronics    500         4         2000
# 243  ORD0244  06-02-25  Smartphone  Electronics    500         4         2000
# 244  ORD0245  04-02-25      Laptop  Electronics    800         1          800
# 248  ORD0249  08-03-25  Smartwatch  Electronics    150         3          450
# 249  ORD0250  19-02-25  Smartphone  Electronics    500         4         2000
#
# ...

# %%
# 7. Display only the orders made using "Amazon Pay".
df3[df3['Payment Method'] == "Amazon Pay"]
# Out:
#     Order ID      Date          Product         Category  Price  Quantity  \
# 2    ORD0003  15-02-25    Running Shoes         Footwear     60         2
# 10   ORD0011  17-02-25             Book            Books     15         2
# 16   ORD0017  01-04-25          T-Shirt         Clothing     20         1
# 17   ORD0018  10-02-25       Smartphone      Electronics    500         2
# 24   ORD0025  02-03-25             Book            Books     15         5
# 26   ORD0027  07-02-25          T-Shirt         Clothing     20         1
# 27   ORD0028  03-02-25       Headphones      Electronics    100         1
# 34   ORD0035  02-04-25           Laptop      Electronics    800         3
# 37   ORD0038  26-03-25           Laptop      Electronics    800         3
# 41   ORD0042  17-03-25       Headphones      Electronics    100         3
# 47   ORD0048  11-02-25          T-Shirt         Clothing     20         5
# 64   ORD0065  16-03-25             Book            Books     15         3
# ...

# %%
# 8. List all orders that are marked as "Cancelled".
df3[df3['Status']=="Cancelled"]
# Out:
#     Order ID      Date          Product         Category  Price  Quantity  \
# 0    ORD0001  14-03-25    Running Shoes         Footwear     60         3
# 2    ORD0003  15-02-25    Running Shoes         Footwear     60         2
# 9    ORD0010  12-03-25       Smartphone      Electronics    500         1
# 13   ORD0014  04-03-25  Washing Machine  Home Appliances    600         3
# 15   ORD0016  26-02-25     Refrigerator  Home Appliances   1200         1
# ..       ...       ...              ...              ...    ...       ...
# 244  ORD0245  04-02-25           Laptop      Electronics    800         1
# 245  ORD0246  17-03-25          T-Shirt         Clothing     20         2
# 246  ORD0247  30-03-25            Jeans         Clothing     40         1
# 247  ORD0248  05-03-25          T-Shirt         Clothing     20         2
# 248  ORD0249  08-03-25       Smartwatch      Electronics    150         3
#
#      Total Sales  Customer Name Customer Location Payment Method     Status
# ...

# %%
# 9. Filter all orders in the "Electronics" category.
df3[df3['Category']=="Electronics"]
# Out:
#     Order ID      Date     Product     Category  Price  Quantity  Total Sales  \
# 1    ORD0002  20-03-25  Headphones  Electronics    100         4          400
# 4    ORD0005  10-03-25  Smartwatch  Electronics    150         3          450
# 6    ORD0007  18-03-25  Smartwatch  Electronics    150         4          600
# 7    ORD0008  02-03-25  Smartphone  Electronics    500         1          500
# 9    ORD0010  12-03-25  Smartphone  Electronics    500         1          500
# ..       ...       ...         ...          ...    ...       ...          ...
# 241  ORD0242  08-03-25  Smartphone  Electronics    500         4         2000
# 243  ORD0244  06-02-25  Smartphone  Electronics    500         4         2000
# 244  ORD0245  04-02-25      Laptop  Electronics    800         1          800
# 248  ORD0249  08-03-25  Smartwatch  Electronics    150         3          450
# 249  ORD0250  19-02-25  Smartphone  Electronics    500         4         2000
#
# ...

# %%
# 10. Show all orders made by the customer "Emma Clark".
df3[df3['Customer Name'] == "Emma Clark"]
# Out:
#     Order ID      Date          Product         Category  Price  Quantity  \
# 0    ORD0001  14-03-25    Running Shoes         Footwear     60         3
# 4    ORD0005  10-03-25       Smartwatch      Electronics    150         3
# 6    ORD0007  18-03-25       Smartwatch      Electronics    150         4
# 16   ORD0017  01-04-25          T-Shirt         Clothing     20         1
# 22   ORD0023  23-02-25             Book            Books     15         1
# 34   ORD0035  02-04-25           Laptop      Electronics    800         3
# 48   ORD0049  18-02-25       Smartphone      Electronics    500         4
# 50   ORD0051  19-02-25             Book            Books     15         1
# 55   ORD0056  19-03-25       Smartwatch      Electronics    150         2
# 62   ORD0063  30-03-25       Smartphone      Electronics    500         5
# 64   ORD0065  16-03-25             Book            Books     15         3
# 77   ORD0078  18-03-25       Smartwatch      Electronics    150         2
# ...

# %%
# 11. Sort the dataset by `Total Sales` in descending order.
df3.sort_values("Total Sales",ascending = False)
# Out:
#     Order ID      Date       Product         Category  Price  Quantity  \
# 125  ORD0126  04-02-25  Refrigerator  Home Appliances   1200         5
# 92   ORD0093  06-03-25  Refrigerator  Home Appliances   1200         5
# 63   ORD0064  13-02-25  Refrigerator  Home Appliances   1200         4
# 68   ORD0069  25-02-25  Refrigerator  Home Appliances   1200         4
# 73   ORD0074  25-03-25  Refrigerator  Home Appliances   1200         4
# ..       ...       ...           ...              ...    ...       ...
# 50   ORD0051  19-02-25          Book            Books     15         1
# 32   ORD0033  04-02-25          Book            Books     15         1
# 123  ORD0124  10-02-25          Book            Books     15         1
# 187  ORD0188  14-02-25          Book            Books     15         1
# 164  ORD0165  14-03-25          Book            Books     15         1
#
#      Total Sales  Customer Name Customer Location Payment Method     Status
# ...

# %%
# 12. Sort orders by `Date` and then by `Price` in ascending order.
df3.sort_values(['Date','Price'],ascending = True)
# Out:
#     Order ID      Date       Product         Category  Price  Quantity  \
# 153  ORD0154  01-03-25    Headphones      Electronics    100         2
# 12   ORD0013  01-03-25        Laptop      Electronics    800         2
# 16   ORD0017  01-04-25       T-Shirt         Clothing     20         1
# 58   ORD0059  01-04-25    Smartwatch      Electronics    150         2
# 207  ORD0208  02-02-25  Refrigerator  Home Appliances   1200         3
# ..       ...       ...           ...              ...    ...       ...
# 66   ORD0067  31-03-25    Headphones      Electronics    100         3
# 191  ORD0192  31-03-25    Headphones      Electronics    100         3
# 229  ORD0230  31-03-25    Headphones      Electronics    100         4
# 110  ORD0111  31-03-25        Laptop      Electronics    800         4
# 142  ORD0143  31-03-25  Refrigerator  Home Appliances   1200         2
#
#      Total Sales  Customer Name Customer Location Payment Method     Status
# ...

# %%
# 13. Display the top 5 most expensive products sold.
most_exp = df3.sort_values('Price',ascending = False)
most_exp.head()
# Out:
#     Order ID      Date       Product         Category  Price  Quantity  \
# 125  ORD0126  04-02-25  Refrigerator  Home Appliances   1200         5
# 60   ORD0061  11-03-25  Refrigerator  Home Appliances   1200         1
# 35   ORD0036  09-02-25  Refrigerator  Home Appliances   1200         2
# 179  ORD0180  04-03-25  Refrigerator  Home Appliances   1200         3
# 172  ORD0173  28-02-25  Refrigerator  Home Appliances   1200         1
#
#      Total Sales  Customer Name Customer Location Payment Method     Status
# 125         6000  Olivia Wilson           Chicago      Gift Card    Pending
# 60          1200     Jane Smith          New York         PayPal  Cancelled
# 35          2400  Sophia Miller            Boston         PayPal  Cancelled
# 179         3600      David Lee            Boston      Gift Card  Completed
# 172         1200  Olivia Wilson           Seattle         PayPal  Completed

# %%
# 14. What is the total sales value for each category?
df3.groupby('Category')['Total Sales'].sum()
# Out:
# Category
# Books                1035
# Clothing             3540
# Electronics        129950
# Footwear             4320
# Home Appliances    105000
# Name: Total Sales, dtype: int64

# %%
# 15. What is the average price and quantity sold per product?
df3.groupby('Product')[['Price','Quantity']].mean()
# Out:
#                   Price  Quantity
# Product
# Book               15.0  2.760000
# Headphones        100.0  2.920000
# Jeans              40.0  3.100000
# Laptop            800.0  3.041667
# Refrigerator     1200.0  2.708333
# Running Shoes      60.0  2.666667
# Smartphone        500.0  2.771429
# Smartwatch        150.0  3.088235
# T-Shirt            20.0  2.650000
# Washing Machine   600.0  2.812500

# %%
# 16. How many orders were placed by each customer?
df3.groupby('Customer Name')['Product'].count()
# Out:
# Customer Name
# Chris White      22
# Daniel Harris    23
# David Lee        26
# Emily Johnson    22
# Emma Clark       32
# Jane Smith       30
# John Doe         26
# Michael Brown    24
# Olivia Wilson    29
# Sophia Miller    16
# Name: Product, dtype: int64

# %%
# 17. What is the total number of products sold by payment method?
df3.groupby('Payment Method')['Product'].count()
# Out:
# Payment Method
# Amazon Pay     41
# Credit Card    54
# Debit Card     53
# Gift Card      42
# PayPal         60
# Name: Product, dtype: int64

# %%
# 18. Count how many times each status ("Pending", "Cancelled", etc.) appears.
df3.groupby('Status')['Product'].count()
# Out:
# Status
# Cancelled    77
# Completed    88
# Pending      85
# Name: Product, dtype: int64

# %%
# 19. Create a new column called `Revenue Per Item` by dividing `Total Sales` by `Quantity`.
df3['Revenue Per Item'] = (df3['Total Sales']//df3['Quantity'])
df3.head(10)
# Out:
#   Order ID      Date        Product     Category  Price  Quantity  \
# 0  ORD0001  14-03-25  Running Shoes     Footwear     60         3
# 1  ORD0002  20-03-25     Headphones  Electronics    100         4
# 2  ORD0003  15-02-25  Running Shoes     Footwear     60         2
# 3  ORD0004  19-02-25  Running Shoes     Footwear     60         3
# 4  ORD0005  10-03-25     Smartwatch  Electronics    150         3
# 5  ORD0006  14-03-25        T-Shirt     Clothing     20         1
# 6  ORD0007  18-03-25     Smartwatch  Electronics    150         4
# 7  ORD0008  02-03-25     Smartphone  Electronics    500         1
# 8  ORD0009  08-03-25        T-Shirt     Clothing     20         3
# 9  ORD0010  12-03-25     Smartphone  Electronics    500         1
#
#    Total Sales  Customer Name Customer Location Payment Method     Status  \
# 0          180     Emma Clark          New York     Debit Card  Cancelled
# 1          400  Emily Johnson     San Francisco     Debit Card    Pending
# ...

# %%
# 20. Add a column that shows the month of the order from the `Date` column.
df3['Date'] = pd.to_datetime(df3['Date'],format='%d-%m-%y')
df3["Month"] = df3['Date'].dt.month
df3.head(10)
# Out:
#   Order ID       Date        Product     Category  Price  Quantity  \
# 0  ORD0001 2025-03-14  Running Shoes     Footwear     60         3
# 1  ORD0002 2025-03-20     Headphones  Electronics    100         4
# 2  ORD0003 2025-02-15  Running Shoes     Footwear     60         2
# 3  ORD0004 2025-02-19  Running Shoes     Footwear     60         3
# 4  ORD0005 2025-03-10     Smartwatch  Electronics    150         3
# 5  ORD0006 2025-03-14        T-Shirt     Clothing     20         1
# 6  ORD0007 2025-03-18     Smartwatch  Electronics    150         4
# 7  ORD0008 2025-03-02     Smartphone  Electronics    500         1
# 8  ORD0009 2025-03-08        T-Shirt     Clothing     20         3
# 9  ORD0010 2025-03-12     Smartphone  Electronics    500         1
#
#    Total Sales  Customer Name Customer Location Payment Method     Status  \
# 0          180     Emma Clark          New York     Debit Card  Cancelled
# 1          400  Emily Johnson     San Francisco     Debit Card    Pending
# ...

# %%
# 21. Create a column `Order Type` that marks orders above 300 as "High Value", else "Regular".
df3['Order Type'] = pd.cut(df3['Price'], bins = [0,300,1200] , labels = ["Regular","High Value"])
df3.head(10)
# Out:
#   Order ID       Date        Product     Category  Price  Quantity  \
# 0  ORD0001 2025-03-14  Running Shoes     Footwear     60         3
# 1  ORD0002 2025-03-20     Headphones  Electronics    100         4
# 2  ORD0003 2025-02-15  Running Shoes     Footwear     60         2
# 3  ORD0004 2025-02-19  Running Shoes     Footwear     60         3
# 4  ORD0005 2025-03-10     Smartwatch  Electronics    150         3
# 5  ORD0006 2025-03-14        T-Shirt     Clothing     20         1
# 6  ORD0007 2025-03-18     Smartwatch  Electronics    150         4
# 7  ORD0008 2025-03-02     Smartphone  Electronics    500         1
# 8  ORD0009 2025-03-08        T-Shirt     Clothing     20         3
# 9  ORD0010 2025-03-12     Smartphone  Electronics    500         1
#
#    Total Sales  Customer Name Customer Location Payment Method     Status  \
# 0          180     Emma Clark          New York     Debit Card  Cancelled
# 1          400  Emily Johnson     San Francisco     Debit Card    Pending
# ...

# %%
# 22. Create a new column combining `Product` and `Category` as `Product Info`.
df3['Product Info'] = df3['Product'] + " " + df3['Category']
df3.head(10)
# Out:
#   Order ID       Date        Product     Category  Price  Quantity  \
# 0  ORD0001 2025-03-14  Running Shoes     Footwear     60         3
# 1  ORD0002 2025-03-20     Headphones  Electronics    100         4
# 2  ORD0003 2025-02-15  Running Shoes     Footwear     60         2
# 3  ORD0004 2025-02-19  Running Shoes     Footwear     60         3
# 4  ORD0005 2025-03-10     Smartwatch  Electronics    150         3
# 5  ORD0006 2025-03-14        T-Shirt     Clothing     20         1
# 6  ORD0007 2025-03-18     Smartwatch  Electronics    150         4
# 7  ORD0008 2025-03-02     Smartphone  Electronics    500         1
# 8  ORD0009 2025-03-08        T-Shirt     Clothing     20         3
# 9  ORD0010 2025-03-12     Smartphone  Electronics    500         1
#
#    Total Sales  Customer Name Customer Location Payment Method     Status  \
# 0          180     Emma Clark          New York     Debit Card  Cancelled
# 1          400  Emily Johnson     San Francisco     Debit Card    Pending
# ...

# %%
df3.head(10)
# Out:
#   Order ID       Date        Product     Category  Price  Quantity  \
# 0  ORD0001 2025-03-14  Running Shoes     Footwear     60         3
# 1  ORD0002 2025-03-20     Headphones  Electronics    100         4
# 2  ORD0003 2025-02-15  Running Shoes     Footwear     60         2
# 3  ORD0004 2025-02-19  Running Shoes     Footwear     60         3
# 4  ORD0005 2025-03-10     Smartwatch  Electronics    150         3
# 5  ORD0006 2025-03-14        T-Shirt     Clothing     20         1
# 6  ORD0007 2025-03-18     Smartwatch  Electronics    150         4
# 7  ORD0008 2025-03-02     Smartphone  Electronics    500         1
# 8  ORD0009 2025-03-08        T-Shirt     Clothing     20         3
# 9  ORD0010 2025-03-12     Smartphone  Electronics    500         1
#
#    Total Sales  Customer Name Customer Location Payment Method     Status  \
# 0          180     Emma Clark          New York     Debit Card  Cancelled
# 1          400  Emily Johnson     San Francisco     Debit Card    Pending
# ...

# %%
# 23. List all unique products in the dataset.
unique_product = []
for i in df3:
    for j in df3['Product']:
        if j in unique_product:
            pass
        else:
            unique_product.append(j)
unique_product
# Out:
# ['Running Shoes',
#  'Headphones',
#  'Smartwatch',
#  'T-Shirt',
#  'Smartphone',
#  'Book',
#  'Jeans',
#  'Laptop',
#  'Washing Machine',
#  'Refrigerator']

# %%
# 24. Count how many orders contain the word "Shoes" in the product name.
df3['Product'].str.contains("Shoes",case = False).sum()
# Out:
# 27

# %%
# 25. Extract the city name from the `Customer Location` column.
df3['Customer Location']
# Out:
# 0           New York
# 1      San Francisco
# 2             Denver
# 3             Dallas
# 4           New York
#            ...
# 245            Miami
# 246           Dallas
# 247           Denver
# 248         New York
# 249          Seattle
# Name: Customer Location, Length: 250, dtype: object

# %%
# 26. Check which customer names contain the letter "o".
name_with_o = df3[df3["Customer Name"].str.contains("o", case= False)]
name_with_o
# Out:
#     Order ID       Date        Product     Category  Price  Quantity  \
# 1    ORD0002 2025-03-20     Headphones  Electronics    100         4
# 2    ORD0003 2025-02-15  Running Shoes     Footwear     60         2
# 3    ORD0004 2025-02-19  Running Shoes     Footwear     60         3
# 5    ORD0006 2025-03-14        T-Shirt     Clothing     20         1
# 7    ORD0008 2025-03-02     Smartphone  Electronics    500         1
# ..       ...        ...            ...          ...    ...       ...
# 240  ORD0241 2025-03-30     Smartphone  Electronics    500         4
# 244  ORD0245 2025-02-04         Laptop  Electronics    800         1
# 246  ORD0247 2025-03-30          Jeans     Clothing     40         1
# 248  ORD0249 2025-03-08     Smartwatch  Electronics    150         3
# 249  ORD0250 2025-02-19     Smartphone  Electronics    500         4
#
#      Total Sales  Customer Name Customer Location Payment Method     Status  \
# ...

# %%
# 27. Show all orders where the product is "Smartwatch" and status is "Pending".
df3[(df3['Product']=="Smartwatch") & (df3['Status']=="Pending")]
# Out:
#     Order ID       Date     Product     Category  Price  Quantity  \
# 4    ORD0005 2025-03-10  Smartwatch  Electronics    150         3
# 39   ORD0040 2025-03-26  Smartwatch  Electronics    150         1
# 43   ORD0044 2025-03-24  Smartwatch  Electronics    150         1
# 53   ORD0054 2025-03-15  Smartwatch  Electronics    150         3
# 65   ORD0066 2025-03-14  Smartwatch  Electronics    150         2
# 70   ORD0071 2025-03-16  Smartwatch  Electronics    150         5
# 97   ORD0098 2025-02-14  Smartwatch  Electronics    150         2
# 152  ORD0153 2025-02-23  Smartwatch  Electronics    150         5
# 163  ORD0164 2025-02-25  Smartwatch  Electronics    150         5
# 173  ORD0174 2025-03-13  Smartwatch  Electronics    150         2
# 239  ORD0240 2025-02-09  Smartwatch  Electronics    150         1
#
#      Total Sales  Customer Name Customer Location Payment Method   Status  \
# 4            450     Emma Clark          New York     Debit Card  Pending
# ...

# %%
# 28. Filter orders where the `Price` is between 50 and 120.
df3[(df3['Price']>50) & (df3['Price']<120)]
# Out:
#     Order ID       Date        Product     Category  Price  Quantity  \
# 0    ORD0001 2025-03-14  Running Shoes     Footwear     60         3
# 1    ORD0002 2025-03-20     Headphones  Electronics    100         4
# 2    ORD0003 2025-02-15  Running Shoes     Footwear     60         2
# 3    ORD0004 2025-02-19  Running Shoes     Footwear     60         3
# 18   ORD0019 2025-03-22  Running Shoes     Footwear     60         3
# 19   ORD0020 2025-03-07     Headphones  Electronics    100         4
# 20   ORD0021 2025-02-05     Headphones  Electronics    100         3
# 27   ORD0028 2025-02-03     Headphones  Electronics    100         1
# 36   ORD0037 2025-02-16     Headphones  Electronics    100         3
# 41   ORD0042 2025-03-17     Headphones  Electronics    100         3
# 45   ORD0046 2025-03-06  Running Shoes     Footwear     60         2
# 52   ORD0053 2025-03-24  Running Shoes     Footwear     60         4
# 66   ORD0067 2025-03-31     Headphones  Electronics    100         3
# ...

# %%
# 29. Display orders made by either "John Doe" or "Emily Johnson".
df3[(df3['Customer Name']=="John Doe") | (df3['Customer Name']=="Emily Johnson")]
# Out:
#     Order ID       Date          Product         Category  Price  Quantity  \
# 1    ORD0002 2025-03-20       Headphones      Electronics    100         4
# 2    ORD0003 2025-02-15    Running Shoes         Footwear     60         2
# 5    ORD0006 2025-03-14          T-Shirt         Clothing     20         1
# 9    ORD0010 2025-03-12       Smartphone      Electronics    500         1
# 14   ORD0015 2025-02-20       Smartwatch      Electronics    150         4
# 15   ORD0016 2025-02-26     Refrigerator  Home Appliances   1200         1
# 29   ORD0030 2025-02-10  Washing Machine  Home Appliances    600         3
# 30   ORD0031 2025-03-24       Smartphone      Electronics    500         1
# 39   ORD0040 2025-03-26       Smartwatch      Electronics    150         1
# 49   ORD0050 2025-03-14            Jeans         Clothing     40         3
# 51   ORD0052 2025-02-24           Laptop      Electronics    800         3
# ...

# %%
# 30. Show orders with "Credit Card" as payment and `Total Sales` over 200.
df3[(df3['Payment Method']=="Credit Card") & (df3['Total Sales']>200)]
# Out:
#     Order ID       Date          Product         Category  Price  Quantity  \
# 9    ORD0010 2025-03-12       Smartphone      Electronics    500         1
# 13   ORD0014 2025-03-04  Washing Machine  Home Appliances    600         3
# 14   ORD0015 2025-02-20       Smartwatch      Electronics    150         4
# 15   ORD0016 2025-02-26     Refrigerator  Home Appliances   1200         1
# 21   ORD0022 2025-03-07     Refrigerator  Home Appliances   1200         4
# 23   ORD0024 2025-03-24     Refrigerator  Home Appliances   1200         3
# 28   ORD0029 2025-02-12       Smartphone      Electronics    500         1
# 44   ORD0045 2025-03-15     Refrigerator  Home Appliances   1200         3
# 51   ORD0052 2025-02-24           Laptop      Electronics    800         3
# 55   ORD0056 2025-03-19       Smartwatch      Electronics    150         2
# 58   ORD0059 2025-04-01       Smartwatch      Electronics    150         2
# ...

# %%
# 31. Drop any duplicate rows if they exist.
df3.drop_duplicates()
# Out:
#     Order ID       Date        Product     Category  Price  Quantity  \
# 0    ORD0001 2025-03-14  Running Shoes     Footwear     60         3
# 1    ORD0002 2025-03-20     Headphones  Electronics    100         4
# 2    ORD0003 2025-02-15  Running Shoes     Footwear     60         2
# 3    ORD0004 2025-02-19  Running Shoes     Footwear     60         3
# 4    ORD0005 2025-03-10     Smartwatch  Electronics    150         3
# ..       ...        ...            ...          ...    ...       ...
# 245  ORD0246 2025-03-17        T-Shirt     Clothing     20         2
# 246  ORD0247 2025-03-30          Jeans     Clothing     40         1
# 247  ORD0248 2025-03-05        T-Shirt     Clothing     20         2
# 248  ORD0249 2025-03-08     Smartwatch  Electronics    150         3
# 249  ORD0250 2025-02-19     Smartphone  Electronics    500         4
#
#      Total Sales  Customer Name Customer Location Payment Method     Status  \
# ...

# %%
# 32. Replace missing values in the `Status` column with "Unknown".
df3['Status'].fillna("Unknown")
# Out:
# 0      Cancelled
# 1        Pending
# 2      Cancelled
# 3        Pending
# 4        Pending
#          ...
# 245    Cancelled
# 246    Cancelled
# 247    Cancelled
# 248    Cancelled
# 249    Completed
# Name: Status, Length: 250, dtype: object

# %%
# 33. Rename the column `Total Sales` to `Revenue`.
df3.rename(columns = {"Total Sales":"Revenue"})
# Out:
#     Order ID       Date        Product     Category  Price  Quantity  Revenue  \
# 0    ORD0001 2025-03-14  Running Shoes     Footwear     60         3      180
# 1    ORD0002 2025-03-20     Headphones  Electronics    100         4      400
# 2    ORD0003 2025-02-15  Running Shoes     Footwear     60         2      120
# 3    ORD0004 2025-02-19  Running Shoes     Footwear     60         3      180
# 4    ORD0005 2025-03-10     Smartwatch  Electronics    150         3      450
# ..       ...        ...            ...          ...    ...       ...      ...
# 245  ORD0246 2025-03-17        T-Shirt     Clothing     20         2       40
# 246  ORD0247 2025-03-30          Jeans     Clothing     40         1       40
# 247  ORD0248 2025-03-05        T-Shirt     Clothing     20         2       40
# 248  ORD0249 2025-03-08     Smartwatch  Electronics    150         3      450
# 249  ORD0250 2025-02-19     Smartphone  Electronics    500         4     2000
#
# ...

# %%
# 35. Count how many unique combinations of Product and Category exist.
unique_combinations = df3[['Product', 'Category']].drop_duplicates()
count = unique_combinations.shape[0]
print("Unique combinations of Product and Category:", count)
# Out:
# Unique combinations of Product and Category: 10

# %% [markdown]
# # THE END
